# %%
import numpy as np
import pandas as pd
import pylab

airbnb= pd.read_csv('C:\\Users\\Ayham\\Documents\\Python Lab\\AirbnbData.csv')

# %%
import os
print (os.getcwd())
# Out:
# C:\Users\Ayham\Documents\Python Lab

# %%
airbnb
# Out:
#         room_id  survey_id    host_id     room_type  country      city  \
# 0      11853600       1441     608475   Shared room      NaN  Montreal
# 1      16618934       1441  109716836   Shared room      NaN  Montreal
# 2       8133701       1441   22509384   Shared room      NaN  Montreal
# 3       7709121       1441   22509384   Shared room      NaN  Montreal
# 4        101717       1441     532616   Shared room      NaN  Montreal
# 5      14105242       1441   84929122   Shared room      NaN  Montreal
# 6       5272180       1441   27289795   Shared room      NaN  Montreal
# 7      19212584       1441  115558837   Shared room      NaN  Montreal
# 8      18505643       1441   42867132   Shared room      NaN  Montreal
# 9      11795355       1441   32164899   Shared room      NaN  Montreal
# 10     11893693       1441   19059347   Shared room      NaN  Montreal
# 11       604189       1441    2990575   Shared room      NaN  Montreal
# ...

# %%
airbnbdata = airbnb[['room_id','room_type','neighborhood', 'reviews', 'overall_satisfaction', 'accommodates', 'bedrooms', 'bathrooms', 'price', 'minstay' ]]

# %%
airbnbdata
# Out:
#         room_id     room_type                              neighborhood  \
# 0      11853600   Shared room                     Le Plateau-Mont-Royal
# 1      16618934   Shared room       Cote des Neiges Notre Dame de Grace
# 2       8133701   Shared room                     Le Plateau-Mont-Royal
# 3       7709121   Shared room                     Le Plateau-Mont-Royal
# 4        101717   Shared room                               Ville-Marie
# 5      14105242   Shared room                                 Westmount
# 6       5272180   Shared room                               Ville-Marie
# 7      19212584   Shared room                              Le Sud-Ouest
# 8      18505643   Shared room                     Le Plateau-Mont-Royal
# 9      11795355   Shared room                               Ville-Marie
# 10     11893693   Shared room       Cote des Neiges Notre Dame de Grace
# 11       604189   Shared room                     Le Plateau-Mont-Royal
# ...

# %%
airbnbdata['bathrooms'].replace(np.nan, 1, inplace=False)
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
# 5        1.0
# 6        1.0
# 7        1.0
# 8        1.0
# 9        1.0
# 10       1.0
# 11       1.0
# 12       1.0
# 13       1.0
# 14       1.0
# 15       1.0
# 16       1.0
# 17       1.0
# 18       1.0
# 19       1.0
# 20       1.0
# 21       1.0
# 22       1.0
# 23       1.0
# 24       1.0
# 25       1.0
# 26       1.0
# 27       1.0
# 28       1.0
# 29       1.0
#         ...
# 15595    1.0
# 15596    1.0
# 15597    1.0
# 15598    1.0
# 15599    1.0
# 15600    1.0
# 15601    1.0
# 15602    1.0
# 15603    1.0
# 15604    1.0
# 15605    1.0
# 15606    1.0
# 15607    1.0
# 15608    1.0
# 15609    1.0
# 15610    1.0
# 15611    1.0
# 15612    1.0
# 15613    1.0
# 15614    1.0
# 15615    1.0
# 15616    1.0
# 15617    1.0
# 15618    1.0
# 15619    1.0
# 15620    1.0
# 15621    1.0
# 15622    1.0
# 15623    1.0
# 15624    1.0
# Name: bathrooms, Length: 15625, dtype: float64

# %%
airbnbdata['minstay'].replace(np.nan, 4, inplace=False)
# Out:
# 0        4.0
# 1        4.0
# 2        4.0
# 3        4.0
# 4        4.0
# 5        4.0
# 6        4.0
# 7        4.0
# 8        4.0
# 9        4.0
# 10       4.0
# 11       4.0
# 12       4.0
# 13       4.0
# 14       4.0
# 15       4.0
# 16       4.0
# 17       4.0
# 18       4.0
# 19       4.0
# 20       4.0
# 21       4.0
# 22       4.0
# 23       4.0
# 24       4.0
# 25       4.0
# 26       4.0
# 27       4.0
# 28       4.0
# 29       4.0
#         ...
# 15595    4.0
# 15596    4.0
# 15597    4.0
# 15598    4.0
# 15599    4.0
# 15600    4.0
# 15601    4.0
# 15602    4.0
# 15603    4.0
# 15604    4.0
# 15605    4.0
# 15606    4.0
# 15607    4.0
# 15608    4.0
# 15609    4.0
# 15610    4.0
# 15611    4.0
# 15612    4.0
# 15613    4.0
# 15614    4.0
# 15615    4.0
# 15616    4.0
# 15617    4.0
# 15618    4.0
# 15619    4.0
# 15620    4.0
# 15621    4.0
# 15622    4.0
# 15623    4.0
# 15624    4.0
# Name: minstay, Length: 15625, dtype: float64

# %%
airbnbdata
# Out:
#         room_id     room_type                              neighborhood  \
# 0      11853600   Shared room                     Le Plateau-Mont-Royal
# 1      16618934   Shared room       Cote des Neiges Notre Dame de Grace
# 2       8133701   Shared room                     Le Plateau-Mont-Royal
# 3       7709121   Shared room                     Le Plateau-Mont-Royal
# 4        101717   Shared room                               Ville-Marie
# 5      14105242   Shared room                                 Westmount
# 6       5272180   Shared room                               Ville-Marie
# 7      19212584   Shared room                              Le Sud-Ouest
# 8      18505643   Shared room                     Le Plateau-Mont-Royal
# 9      11795355   Shared room                               Ville-Marie
# 10     11893693   Shared room       Cote des Neiges Notre Dame de Grace
# 11       604189   Shared room                     Le Plateau-Mont-Royal
# ...

# %%
airbnbdataclean=airbnbdata[(airbnbdata.reviews >0) | (airbnbdata.overall_satisfaction)>0]

# %%
airbnbdataclean
# Out:
#         room_id     room_type                          neighborhood  reviews  \
# 2       8133701   Shared room                 Le Plateau-Mont-Royal        4
# 3       7709121   Shared room                 Le Plateau-Mont-Royal        8
# 4        101717   Shared room                           Ville-Marie       77
# 6       5272180   Shared room                           Ville-Marie        4
# 8      18505643   Shared room                 Le Plateau-Mont-Royal        1
# 9      11795355   Shared room                           Ville-Marie       29
# 10     11893693   Shared room   Cote des Neiges Notre Dame de Grace        1
# 11       604189   Shared room                 Le Plateau-Mont-Royal      127
# 12     19039836   Shared room             Rosemont-La Petite-Patrie        3
# 20      1217907   Shared room                           Ville-Marie       73
# 21      3344420   Shared room                           Ville-Marie        1
# ...

# %%
airbnbdataclean[['price','minstay']].astype(float)
# Out:
#        price  minstay
# 2       57.0      4.0
# 3       41.0      4.0
# 4       35.0      4.0
# 6       20.0      4.0
# 8       28.0      4.0
# 9       28.0      4.0
# 10      33.0      4.0
# 11      38.0      4.0
# 12      28.0      4.0
# 20     119.0      4.0
# 21      84.0      4.0
# 22      84.0      4.0
# 23      72.0      4.0
# 25      53.0      4.0
# 29      48.0      4.0
# 30      43.0      4.0
# 31      57.0      4.0
# 32      44.0      4.0
# 33      48.0      4.0
# 35      48.0      4.0
# 36      52.0      4.0
# 38      24.0      4.0
# 42      13.0      4.0
# 47      14.0      4.0
# 49      16.0      4.0
# 50      24.0      4.0
# 55      39.0      4.0
# 56      40.0      4.0
# 57      38.0      4.0
# 58      24.0      4.0
# ...      ...      ...
# 15585   20.0      4.0
# 15587   21.0      4.0
# 15588   20.0      4.0
# 15590   27.0      4.0
# 15591   24.0      4.0
# 15592   39.0      4.0
# 15593   15.0      4.0
# 15594   24.0      4.0
# 15595   20.0      4.0
# ...

# %%
airbnbdataclean['Total'] = airbnbdataclean['price'].multiply(airbnbdataclean['minstay'])
# Out:
# C:\Users\Ayham\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#max between reviews, overall_satisfaction and price
airbnbdataclean[["reviews", "overall_satisfaction", "price"]].max(axis=1)
# Out:
# 2         57.0
# 3         41.0
# 4         77.0
# 6         20.0
# 8         28.0
# 9         29.0
# 10        33.0
# 11       127.0
# 12        28.0
# 20       119.0
# 21        84.0
# 22        84.0
# 23        72.0
# 25        53.0
# 29        48.0
# 30        43.0
# 31        57.0
# 32        44.0
# 33        48.0
# 35        48.0
# 36        52.0
# 38        24.0
# 42        13.0
# 47        14.0
# 49        16.0
# 50        24.0
# 55        39.0
# 56        40.0
# 57        38.0
# 58        24.0
#          ...
# 15585     20.0
# 15587     23.0
# 15588     20.0
# 15590     27.0
# 15591     24.0
# 15592     39.0
# 15593     15.0
# 15594     24.0
# 15595    114.0
# 15596     39.0
# 15597     35.0
# 15598     18.0
# 15599     26.0
# 15600     62.0
# 15601     33.0
# 15602     25.0
# 15603     21.0
# 15604     70.0
# 15605     36.0
# 15606    195.0
# 15607     40.0
# 15608     21.0
# 15612     23.0
# 15615     32.0
# 15616     20.0
# 15620     74.0
# 15621     19.0
# ...

# %%
fig, axes = plt.subplots(1,2 ,figsize=(12,14))
n=airbnbdataclean['reviews']
axes[0].hist(n)
axes[0].set_title("Reviews")
axes[0].set_xlim((min(n),max(n)))

axes[1].hist(n, cumulative=True, bins=50)
axes[1].set_title("Cumulative detailed Review")
axes[1].set_xlim((min(n),max(n)));
